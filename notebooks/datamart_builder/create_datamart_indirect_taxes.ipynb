# %% [markdown]
# # Tipos impositivos por categoría de gasto (2016)

# %%
import pandas as pd

# %%
import pandas as pd

# Tax data for 2025 by category code
tax_data_2025 = [
  {'code': '11', 'iva': 11,   'igic': 4,   'ipsi': 2},
  {'code': '12', 'iva': 10,  'igic': 7,   'ipsi': 0.5},
  {'code': '21', 'iva': 21,  'igic': 13.5,'ipsi': 10},
  {'code': '22', 'iva': 21,  'igic': 20,  'ipsi': 10},
  {'code': '31', 'iva': 21,  'igic': 3,   'ipsi': 4},
  {'code': '32', 'iva': 21,  'igic': 3,   'ipsi': 4},
  {'code': '41', 'iva': 0,   'igic': 0,   'ipsi': 4},
  {'code': '43', 'iva': 10,  'igic': 7,   'ipsi': 4},
  {'code': '44', 'iva': 10,  'igic': 0,   'ipsi': 0.5},
  {'code': '45', 'iva': 21,  'igic': 3,   'ipsi': 1},
  {'code': '51', 'iva': 21,  'igic': 7,   'ipsi': 4},
  {'code': '52', 'iva': 21,  'igic': 7,   'ipsi': 4},
  {'code': '53', 'iva': 21,  'igic': 7,   'ipsi': 4},
  {'code': '54', 'iva': 21,  'igic': 7,   'ipsi': 4},
  {'code': '55', 'iva': 21,  'igic': 7,   'ipsi': 4},
  {'code': '56', 'iva': 21,  'igic': 7,   'ipsi': 4},
  {'code': '61', 'iva': 4,   'igic': 0,   'ipsi': 0.5},
  {'code': '62', 'iva': 0,   'igic': 0,   'ipsi': 4},
  {'code': '63', 'iva': 0,   'igic': 0,   'ipsi': 4},
  {'code': '71', 'iva': 21,  'igic': 9.5, 'ipsi': 4},
  {'code': '72', 'iva': 21,  'igic': 7,   'ipsi': 4},
  {'code': '73', 'iva': 10,  'igic': 7,   'ipsi': 0.5},
  {'code': '81', 'iva': 21,  'igic': 7,   'ipsi': 4},
  {'code': '82', 'iva': 21,  'igic': 7,   'ipsi': 4},
  {'code': '83', 'iva': 21,  'igic': 7,   'ipsi': 8},
  {'code': '91', 'iva': 21,  'igic': 7,   'ipsi': 4},
  {'code': '92', 'iva': 21,  'igic': 7,   'ipsi': 4},
  {'code': '93', 'iva': 21,  'igic': 7,   'ipsi': 4},
  {'code': '94', 'iva': 10,  'igic': 7,   'ipsi': 4},
  {'code': '95', 'iva': 21,  'igic': 0,   'ipsi': 4},
  {'code': '96', 'iva': 10,  'igic': 7,   'ipsi': 4},
  {'code': '101', 'iva': 0,   'igic': 0,   'ipsi': 4},
  {'code': '102', 'iva': 0,   'igic': 0,   'ipsi': 4},
  {'code': '103', 'iva': 0,   'igic': 0,   'ipsi': 4},
  {'code': '104', 'iva': 0,   'igic': 0,   'ipsi': 4},
  {'code': '111', 'iva': 10,  'igic': 7,   'ipsi': 2},
  {'code': '112', 'iva': 10,  'igic': 7,   'ipsi': 2},
  {'code': '121', 'iva': 21,  'igic': 7,   'ipsi': 4},
  {'code': '123', 'iva': 21,  'igic': 7,   'ipsi': 4},
  {'code': '124', 'iva': 10,  'igic': 0,   'ipsi': 4},
  {'code': '125', 'iva': 21,  'igic': 4,   'ipsi': 4},
  {'code': '126', 'iva': 0,   'igic': 4,   'ipsi': 4},
  {'code': '127', 'iva': 21,  'igic': 4,   'ipsi': 4},
  {'code': '128', 'iva': 10,   'igic': 4,   'ipsi': 4}
]

# %%
# Convert to DataFrame
datamart_df = pd.DataFrame(tax_data_2025)

# Display or save the datamart
datamart_df
# Out:
#    code  iva  igic  ipsi
# 0    11   11   4.0   2.0
# 1    12   10   7.0   0.5
# 2    21   21  13.5  10.0
# 3    22   21  20.0  10.0
# 4    31   21   3.0   4.0
# 5    32   21   3.0   4.0
# 6    41    0   0.0   4.0
# 7    43   10   7.0   4.0
# 8    44   10   0.0   0.5
# 9    45   21   3.0   1.0
# 10   51   21   7.0   4.0
# 11   52   21   7.0   4.0
# 12   53   21   7.0   4.0
# 13   54   21   7.0   4.0
# 14   55   21   7.0   4.0
# 15   56   21   7.0   4.0
# 16   61    4   0.0   0.5
# 17   62    0   0.0   4.0
# 18   63    0   0.0   4.0
# 19   71   21   9.5   4.0
# 20   72   21   7.0   4.0
# 21   73   10   7.0   0.5
# 22   81   21   7.0   4.0
# 23   82   21   7.0   4.0
# 24   83   21   7.0   8.0
# 25   91   21   7.0   4.0
# 26   92   21   7.0   4.0
# 27   93   21   7.0   4.0
# 28   94   10   7.0   4.0
# 29   95   21   0.0   4.0
# 30   96   10   7.0   4.0
# 31  101    0   0.0   4.0
# 32  102    0   0.0   4.0
# 33  103    0   0.0   4.0
# 34  104    0   0.0   4.0
# 35  111   10   7.0   2.0
# ...

# %%
datamart_pivot = datamart_df.set_index('code').T

# %%
pd.set_option('display.max_columns', None)  # Show all columns in the output
datamart_pivot
# Out:
# code    11    12    21    22    31    32   41    43    44    45    51    52  \
# iva   11.0  10.0  21.0  21.0  21.0  21.0  0.0  10.0  10.0  21.0  21.0  21.0
# igic   4.0   7.0  13.5  20.0   3.0   3.0  0.0   7.0   0.0   3.0   7.0   7.0
# ipsi   2.0   0.5  10.0  10.0   4.0   4.0  4.0   4.0   0.5   1.0   4.0   4.0
#
# code    53    54    55    56   61   62   63    71    72    73    81    82  \
# iva   21.0  21.0  21.0  21.0  4.0  0.0  0.0  21.0  21.0  10.0  21.0  21.0
# igic   7.0   7.0   7.0   7.0  0.0  0.0  0.0   9.5   7.0   7.0   7.0   7.0
# ipsi   4.0   4.0   4.0   4.0  0.5  4.0  4.0   4.0   4.0   0.5   4.0   4.0
#
# code    83    91    92    93    94    95    96  101  102  103  104   111  \
# iva   21.0  21.0  21.0  21.0  10.0  21.0  10.0  0.0  0.0  0.0  0.0  10.0
# igic   7.0   7.0   7.0   7.0   7.0   0.0   7.0  0.0  0.0  0.0  0.0   7.0
# ipsi   8.0   4.0   4.0   4.0   4.0   4.0   4.0  4.0  4.0  4.0  4.0   2.0
#
# code   112   121   123   124   125  126   127   128
# ...

# %%
datamart_df.to_csv("../../datamarts/tax_datamart_2025.tsv", index=False, sep="\t")

# %% [markdown]
# ## 🧾 Tipos impositivos vigentes en 2025 por territorio
#
# ### 🇪🇸 IVA (Impuesto sobre el Valor Añadido) – Península y Baleares
#
# - **Tipo general**: 21%
# - **Tipo reducido**: 10%
# - **Tipo superreducido**: 4%
# - **Tipo cero**: 0%
#
# Aplicaciones comunes:
# - **4%**: Alimentos básicos (pan, leche, huevos, frutas, verduras), libros, periódicos y medicamentos.
# - **10%**: Alimentos no básicos, transporte de viajeros, hostelería, viviendas de nueva construcción.
# - **21%**: Resto de bienes y servicios no incluidos en los anteriores.
#
# ### 🇮🇨 IGIC (Impuesto General Indirecto Canario) – Canarias
#
# - **Tipo general**: 7%
# - **Tipo reducido**: 3%
# - **Tipo cero**: 0%
# - **Tipo incrementado**: 9,5% y 13,5%
# - **Tipo especial**: 20%
#
# Aplicaciones comunes:
# - **0%**: Bienes y servicios de primera necesidad (alimentos básicos, medicamentos, libros).
# - **3%**: Productos textiles o químicos, suministros.
# - **7%**: Tipo general.
# - **9,5% / 13,5%**: Vehículos, bebidas alcohólicas, tabaco, productos de lujo.
# - **20%**: Tabaco negro y rubio, sucedáneos del tabaco.
#
# ### 🇪🇦 IPSI (Impuesto sobre la Producción, los Servicios y la Importación) – Ceuta y Melilla
#
# - **Tipo general**: 4%
# - **Tipos reducidos**: 0,5%, 1%, 2%
# - **Tipos incrementados**: 8%, 10%
#
# Aplicaciones comunes:
# - **0,5%**: Viviendas nuevas, protección oficial, transporte de viajeros.
# - **1%**: Taxis, cafeterías, bares, consumo eléctrico.
# - **2%**: Restaurantes de dos tenedores o más.
# - **4%**: Reformas, mejoras, inmuebles.
# - **8% / 10%**: Servicios electrónicos, construcción.
#
# ---
#
# ## 🧠 Justificación de la asignación de tipos impositivos a las categorías de gasto
#
# Para asignar los tipos impositivos (IVA, IGIC e IPSI) a las 45 categorías de gasto del datamart, se aplicó una metodología basada en:
#
# ### 1. Correspondencia conceptual
# Se asignó el tipo más coherente con el contenido de cada categoría.
# Ejemplo: `01.1 PRODUCTOS ALIMENTICIOS` → IVA 4% por tratarse de alimentos básicos.
#
# - **IGIC**: 0% (alimentos de primera necesidad están exentos).
# - **IPSI**: 0,5% (tipo simbólico para alimentos en Ceuta y Melilla).
#
# ### 2. Legislación oficial consultada
# - **IVA**: Ley 37/1992 y sus actualizaciones (BOE).
# - **IGIC**: Decreto Legislativo 1/1994 y portal oficial de la Agencia Tributaria Canaria.
# - **IPSI**: Ordenanzas fiscales de Ceuta y Melilla (años 2021–2024).
#
# ### 3. Asignación funcional
# Cuando no existía equivalencia directa (e.g. `remesas`, `protección social`), se asignó el **0%** por su carácter **exento o no sujeto**.
#
# Servicios sociales, educativos o sanitarios se consideraron de **interés general** y se les aplicó un tipo reducido o nulo.
#
# ### 4. Actualización con valores de 2025
# Los tipos asignados reflejan la situación normativa vigente en 2025.
# En ausencia de cambios significativos en la legislación, se han mantenido los valores de 2023–2024.
#
# ### 5. Adaptación de códigos
# Los códigos como `"01.1"` fueron convertidos a `"011"` para facilitar su uso como claves en bases de datos y modelos.
#
# ---
#
# 🔗 **Fuentes principales**:
# - Agencia Tributaria Española: [www.agenciatributaria.es](https://www.agenciatributaria.es)
# - Agencia Tributaria Canaria: [www.gobiernodecanarias.org/tributos](https://www.gobiernodecanarias.org/tributos)
# - Ordenanzas fiscales de Ceuta y Melilla (2021–2024)
